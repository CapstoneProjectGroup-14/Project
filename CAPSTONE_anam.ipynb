# %%
import numpy as np 
import pandas as pd
from pandas import DataFrame
import nltk

import seaborn as sb

import matplotlib.pyplot as plt

# %%
df=pd.read_json("yelp_academic_dataset_tip.json",lines=True)

# %%
df.shape
# Out:
# (1223094, 5)

# %%
df.head()
# Out:
#                   user_id             business_id  \
# 0  UPw5DWs_b-e2JRBS-t37Ag  VaKXUpmWTTWDKbpJ3aQdMw
# 1  Ocha4kZBHb4JK0lOWvE0sg  OPiPeoJiv92rENwbq76orA
# 2  jRyO2V1pA4CdVVqCIOPc1Q  5KheTjYPu1HcQzQFtm4_vw
# 3  FuTJWFYm4UKqewaosss1KA  TkoyGi8J7YFjA6SbaRzrxg
# 4  LUlKtaM3nXd-E4N4uOk_fQ  AkL6Ous6A1atZejfZXn1Bg
#
#                                                 text                date  \
# 0  Great for watching games, ufc, and whatever el... 2014-03-27 03:51:24
# 1  Happy Hour 2-4 daily with 1/2 price drinks and... 2013-05-25 06:00:56
# 2  Good chips and salsa. Loud at times. Good serv... 2011-12-26 01:46:17
# 3  The setting and decoration here is amazing. Co... 2014-03-23 21:32:49
# 4  Molly is definately taking a picture with Sant... 2012-10-06 00:19:27
#
#    compliment_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
df
# Out:
#                         user_id             business_id  \
# 0        UPw5DWs_b-e2JRBS-t37Ag  VaKXUpmWTTWDKbpJ3aQdMw
# 1        Ocha4kZBHb4JK0lOWvE0sg  OPiPeoJiv92rENwbq76orA
# 2        jRyO2V1pA4CdVVqCIOPc1Q  5KheTjYPu1HcQzQFtm4_vw
# 3        FuTJWFYm4UKqewaosss1KA  TkoyGi8J7YFjA6SbaRzrxg
# 4        LUlKtaM3nXd-E4N4uOk_fQ  AkL6Ous6A1atZejfZXn1Bg
# ...                         ...                     ...
# 1223089  nus5X9JKgU_SzfAL4vhJrg  qdwwiRKwnhdlr9QcgJuzbg
# 1223090  95wqYGU6-OiHqRPZP0uAWw  wrs4Zbz17q_G49AIRxRPVw
# 1223091  HtLaONYabidSxMS1eGHcXA  wEc4JE2NYQr1RnGjGr4q7w
# 1223092  T4R5ZKfcGt1GIAgjCh67eA  n5Hc_iMVkyxcS0SXiBCbOQ
# 1223093  2Ag223bd4OtQOnc-F067rQ  wEoaR5WKNtLOLyR1z0TYdg
#
#                                                       text  \
# 0        Great for watching games, ufc, and whatever el...
# 1        Happy Hour 2-4 daily with 1/2 price drinks and...
# 2        Good chips and salsa. Loud at times. Good serv...
# 3        The setting and decoration here is amazing. Co...
# 4        Molly is definately taking a picture with Sant...
# ...                                                    ...
# 1223089                Very good class, great instructor!!
# 1223090                                     Excellent food
# 1223091     Jess is the best bartender!! Go check her out!
# 1223092  Excellent food and AMAZING service by Anneliese!!
# 1223093                                         Funnnnn!!!
#
#                        date  compliment_count
# 0       2014-03-27 03:51:24                 0
# 1       2013-05-25 06:00:56                 0
# 2       2011-12-26 01:46:17                 0
# 3       2014-03-23 21:32:49                 0
# 4       2012-10-06 00:19:27                 0
# ...                     ...               ...
# 1223089 2018-08-05 20:58:09                 0
# 1223090 2018-08-15 18:05:22                 0
# 1223091 2018-10-02 03:34:58                 0
# 1223092 2018-10-13 16:57:50                 0
# 1223093 2018-11-10 03:17:18                 0
#
# [1223094 rows x 5 columns]

# %%
df1=pd.read_csv("processed.csv")

# %%
df1
# Out:
#                                                  Column1
# 0      processed_acl/                                ...
# 1      your:2 by_disney:1 many_drug:1 can't_even:1 cl...
# 2      old:1 complicated:1 fun_to:2 moves:2 breaking:...
# 3      enjoy_what:1 find_that:1 add_some:1 and_when:1...
# 4      holes:1 movie_however:2 shooting_fish:1 not_su...
# ...                                                  ...
# 27676  canon_mp500:1 favorite:1 at_all:1 printing:2 <...
# 27677  i_think:1 your:1 papers_like:1 using_the:1 ben...
# 27678  i:1 well:3 <num>_months:1 with_reading:1 that_...
# 27679  gps_units:1 office_building:1 is_extremely:1 h...
# 27680  a_compact:1 hp:1 hp_compaq:1 streets_and:1 my:...
#
# [27681 rows x 1 columns]

# %%
df2=pd.read_csv("CAPEP.csv", encoding= 'unicode_escape')

# %%
df2
# Out:
#                                                     name         brand  \
# 0      AmazonBasics AAA Performance Alkaline Batterie...  Amazonbasics
# 1      AmazonBasics AAA Performance Alkaline Batterie...  Amazonbasics
# 2      AmazonBasics AAA Performance Alkaline Batterie...  Amazonbasics
# 3      AmazonBasics AAA Performance Alkaline Batterie...  Amazonbasics
# 4      AmazonBasics AAA Performance Alkaline Batterie...  Amazonbasics
# ...                                                  ...           ...
# 33327  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...        Amazon
# 33328  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...        Amazon
# 33329  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...        Amazon
# 33330  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...        Amazon
# 33331  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...        Amazon
#
#                                               categories primaryCategories  \
# 0      AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 1      AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 2      AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 3      AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 4      AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# ...                                                  ...               ...
# 33327  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
# 33328  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
# 33329  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
# 33330  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
# 33331  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
#
#                                                     keys  manufacturer  \
# 0      amazonbasics/hl002619,amazonbasicsaaaperforman...  AmazonBasics
# 1      amazonbasics/hl002619,amazonbasicsaaaperforman...  AmazonBasics
# 2      amazonbasics/hl002619,amazonbasicsaaaperforman...  AmazonBasics
# 3      amazonbasics/hl002619,amazonbasicsaaaperforman...  AmazonBasics
# 4      amazonbasics/hl002619,amazonbasicsaaaperforman...  AmazonBasics
# ...                                                  ...           ...
# 33327  841667103150,0841667103150,firetabletwithalexa...        Amazon
# 33328  841667103150,0841667103150,firetabletwithalexa...        Amazon
# 33329  841667103150,0841667103150,firetabletwithalexa...        Amazon
# 33330  841667103150,0841667103150,firetabletwithalexa...        Amazon
# 33331  841667103150,0841667103150,firetabletwithalexa...        Amazon
#
#                            date  Genuine_non_genuine  Genuine_non Genuine  \
# 0      2017-03-02T00:00:00.000Z                 True                  1.0
# 1      2016-08-31T00:00:00.000Z                 True                  1.0
# 2      2016-12-06T00:00:00.000Z                 True                  1.0
# 3      2016-03-28T00:00:00.000Z                 True                  1.0
# 4      2017-04-22T00:00:00.000Z                 True                  1.0
# ...                         ...                  ...                  ...
# 33327  2016-10-21T00:00:00.000Z                 True                  1.0
# 33328  2016-08-10T00:00:00.000Z                 True                  1.0
# 33329  2016-06-05T00:00:00.000Z                False                  0.0
# 33330  2016-09-02T00:00:00.000Z                 True                  1.0
# 33331  2016-05-19T00:00:00.000Z                False                  0.0
#
#        rating                                  sourceURLs_review  \
# 0           3  https://www.amazon.com/product-reviews/B00QWO9...
# 1           4  https://www.amazon.com/product-reviews/B00QWO9...
# 2           5  https://www.amazon.com/product-reviews/B00QWO9...
# 3           5  https://www.amazon.com/product-reviews/B00QWO9...
# 4           5  https://www.amazon.com/product-reviews/B00QWO9...
# ...       ...                                                ...
# 33327       5  http://reviews.bestbuy.com/3545/5025900/review...
# 33328       5  http://reviews.bestbuy.com/3545/5025900/review...
# 33329       4  http://reviews.bestbuy.com/3545/5025900/review...
# 33330       5  http://reviews.bestbuy.com/3545/5025900/review...
# 33331       5  http://reviews.bestbuy.com/3545/5025900/review...
#
#                                                  reviews  \
# 0      I order 3 of them and one of the item is bad q...
# 1      Bulk is always the less expensive way to go fo...
# 2      Well they are not Duracell but for the price i...
# 3      Seem to work as well as name brand batteries a...
# 4      These batteries are very long lasting the pric...
# ...                                                  ...
# 33327  This is a great tablet for the price. Amazon i...
# 33328  This tablet is the perfect size and so easy to...
# 33329  Purchased this for my son. Has room to upgrade...
# 33330  I had some thoughts about getting this for a 5...
# 33331  this is a steal, have 8 gb model as well.This ...
#
#                                            reviews_title          username  \
# 0      ... 3 of them and one of the item is bad quali...        Byger yang
# 1      ... always the less expensive way to go for pr...              ByMG
# 2      ... are not Duracell but for the price i am ha...  BySharon Lambert
# 3      ... as well as name brand batteries at a much ...     Bymark sexson
# 4      ... batteries are very long lasting the price ...           Bylinda
# ...                                                  ...               ...
# 33327                                       Good product             litle
# 33328                                       Great Tablet            gracie
# 33329                    Great for kids or smaller needs              Hawk
# 33330                       Very sturdy for a 5 year old           Mrbilly
# 33331                                great little tablet            tabman
#
#                                               sourceURLs
# 0      https://www.barcodable.com/upc/841710106442,ht...
# 1      https://www.barcodable.com/upc/841710106442,ht...
# 2      https://www.barcodable.com/upc/841710106442,ht...
# 3      https://www.barcodable.com/upc/841710106442,ht...
# 4      https://www.barcodable.com/upc/841710106442,ht...
# ...                                                  ...
# 33327  https://www.barcodable.com/upc/841667103150,ht...
# 33328  https://www.barcodable.com/upc/841667103150,ht...
# 33329  https://www.barcodable.com/upc/841667103150,ht...
# 33330  https://www.barcodable.com/upc/841667103150,ht...
# 33331  https://www.barcodable.com/upc/841667103150,ht...
#
# [33332 rows x 15 columns]

# %%
df2.head()
# Out:
#                                                 name         brand  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  Amazonbasics
# 1  AmazonBasics AAA Performance Alkaline Batterie...  Amazonbasics
# 2  AmazonBasics AAA Performance Alkaline Batterie...  Amazonbasics
# 3  AmazonBasics AAA Performance Alkaline Batterie...  Amazonbasics
# 4  AmazonBasics AAA Performance Alkaline Batterie...  Amazonbasics
#
#                                           categories primaryCategories  \
# 0  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 1  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 2  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 3  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
# 4  AA,AAA,Health,Electronics,Health & Household,C...   Health & Beauty
#
#                                                 keys  manufacturer  \
# 0  amazonbasics/hl002619,amazonbasicsaaaperforman...  AmazonBasics
# 1  amazonbasics/hl002619,amazonbasicsaaaperforman...  AmazonBasics
# 2  amazonbasics/hl002619,amazonbasicsaaaperforman...  AmazonBasics
# 3  amazonbasics/hl002619,amazonbasicsaaaperforman...  AmazonBasics
# 4  amazonbasics/hl002619,amazonbasicsaaaperforman...  AmazonBasics
#
#                        date  Genuine_non_genuine  Genuine_non Genuine  rating  \
# 0  2017-03-02T00:00:00.000Z                 True                  1.0       3
# 1  2016-08-31T00:00:00.000Z                 True                  1.0       4
# 2  2016-12-06T00:00:00.000Z                 True                  1.0       5
# 3  2016-03-28T00:00:00.000Z                 True                  1.0       5
# 4  2017-04-22T00:00:00.000Z                 True                  1.0       5
#
#                                    sourceURLs_review  \
# 0  https://www.amazon.com/product-reviews/B00QWO9...
# 1  https://www.amazon.com/product-reviews/B00QWO9...
# 2  https://www.amazon.com/product-reviews/B00QWO9...
# 3  https://www.amazon.com/product-reviews/B00QWO9...
# 4  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                              reviews  \
# 0  I order 3 of them and one of the item is bad q...
# 1  Bulk is always the less expensive way to go fo...
# 2  Well they are not Duracell but for the price i...
# 3  Seem to work as well as name brand batteries a...
# 4  These batteries are very long lasting the pric...
#
#                                        reviews_title          username  \
# 0  ... 3 of them and one of the item is bad quali...        Byger yang
# 1  ... always the less expensive way to go for pr...              ByMG
# 2  ... are not Duracell but for the price i am ha...  BySharon Lambert
# 3  ... as well as name brand batteries at a much ...     Bymark sexson
# 4  ... batteries are very long lasting the price ...           Bylinda
#
#                                           sourceURLs
# 0  https://www.barcodable.com/upc/841710106442,ht...
# 1  https://www.barcodable.com/upc/841710106442,ht...
# 2  https://www.barcodable.com/upc/841710106442,ht...
# 3  https://www.barcodable.com/upc/841710106442,ht...
# 4  https://www.barcodable.com/upc/841710106442,ht...

# %%
df2.tail()
# Out:
#                                                     name   brand  \
# 33327  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...  Amazon
# 33328  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...  Amazon
# 33329  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...  Amazon
# 33330  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...  Amazon
# 33331  Fire Tablet with Alexa, 7" Display, 16 GB, Mag...  Amazon
#
#                                               categories primaryCategories  \
# 33327  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
# 33328  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
# 33329  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
# 33330  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
# 33331  Tablets,Fire Tablets,Electronics,iPad & Tablet...       Electronics
#
#                                                     keys manufacturer  \
# 33327  841667103150,0841667103150,firetabletwithalexa...       Amazon
# 33328  841667103150,0841667103150,firetabletwithalexa...       Amazon
# 33329  841667103150,0841667103150,firetabletwithalexa...       Amazon
# 33330  841667103150,0841667103150,firetabletwithalexa...       Amazon
# 33331  841667103150,0841667103150,firetabletwithalexa...       Amazon
#
#                            date  Genuine_non_genuine  Genuine_non Genuine  \
# 33327  2016-10-21T00:00:00.000Z                 True                  1.0
# 33328  2016-08-10T00:00:00.000Z                 True                  1.0
# 33329  2016-06-05T00:00:00.000Z                False                  0.0
# 33330  2016-09-02T00:00:00.000Z                 True                  1.0
# 33331  2016-05-19T00:00:00.000Z                False                  0.0
#
#        rating                                  sourceURLs_review  \
# 33327       5  http://reviews.bestbuy.com/3545/5025900/review...
# 33328       5  http://reviews.bestbuy.com/3545/5025900/review...
# 33329       4  http://reviews.bestbuy.com/3545/5025900/review...
# 33330       5  http://reviews.bestbuy.com/3545/5025900/review...
# 33331       5  http://reviews.bestbuy.com/3545/5025900/review...
#
#                                                  reviews  \
# 33327  This is a great tablet for the price. Amazon i...
# 33328  This tablet is the perfect size and so easy to...
# 33329  Purchased this for my son. Has room to upgrade...
# 33330  I had some thoughts about getting this for a 5...
# 33331  this is a steal, have 8 gb model as well.This ...
#
#                          reviews_title username  \
# 33327                     Good product    litle
# 33328                     Great Tablet   gracie
# 33329  Great for kids or smaller needs     Hawk
# 33330     Very sturdy for a 5 year old  Mrbilly
# 33331              great little tablet   tabman
#
#                                               sourceURLs
# 33327  https://www.barcodable.com/upc/841667103150,ht...
# 33328  https://www.barcodable.com/upc/841667103150,ht...
# 33329  https://www.barcodable.com/upc/841667103150,ht...
# 33330  https://www.barcodable.com/upc/841667103150,ht...
# 33331  https://www.barcodable.com/upc/841667103150,ht...

# %%
df2.shape
# Out:
# (33332, 15)

# %%
import nltk.classify.util
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from nltk.classify import NaiveBayesClassifier
import numpy as np
import re
import string
import nltk
# %matplotlib inline

# %%
permanent = df2[['rating' , 'reviews' , 'reviews_title' , 'username']]
print(permanent.isnull().sum()) #Checking for null values
permanent.head()
# Out:
# rating            0
# reviews           0
# reviews_title    13
# username          0
# dtype: int64
#    rating                                            reviews  \
# 0       3  I order 3 of them and one of the item is bad q...
# 1       4  Bulk is always the less expensive way to go fo...
# 2       5  Well they are not Duracell but for the price i...
# 3       5  Seem to work as well as name brand batteries a...
# 4       5  These batteries are very long lasting the pric...
#
#                                        reviews_title          username
# 0  ... 3 of them and one of the item is bad quali...        Byger yang
# 1  ... always the less expensive way to go for pr...              ByMG
# 2  ... are not Duracell but for the price i am ha...  BySharon Lambert
# 3  ... as well as name brand batteries at a much ...     Bymark sexson
# 4  ... batteries are very long lasting the price ...           Bylinda

# %%
check =  permanent[permanent["reviews_title"].isnull()]
check.head()
# Out:
#        rating                                            reviews  \
# 28666       5  I love it. It does so much and is so easy to u...
# 28667       5  I love the Echo show. I have found so many use...
# 28679       5  I bought the echo show for my mom for her birt...
# 28727       5  This was bought for a gift. But it looks nice....
# 28808       5  Its a lot more then we expected.this is a wond...
#
#       reviews_title username
# 28666           NaN    Cindy
# 28667           NaN   Plucky
# 28679           NaN   Kelsey
# 28727           NaN  Mchiare
# 28808           NaN   BillyD

# %%
senti= permanent[permanent["reviews_title"].notnull()]
senti.head()
# Out:
#    rating                                            reviews  \
# 0       3  I order 3 of them and one of the item is bad q...
# 1       4  Bulk is always the less expensive way to go fo...
# 2       5  Well they are not Duracell but for the price i...
# 3       5  Seem to work as well as name brand batteries a...
# 4       5  These batteries are very long lasting the pric...
#
#                                        reviews_title          username
# 0  ... 3 of them and one of the item is bad quali...        Byger yang
# 1  ... always the less expensive way to go for pr...              ByMG
# 2  ... are not Duracell but for the price i am ha...  BySharon Lambert
# 3  ... as well as name brand batteries at a much ...     Bymark sexson
# 4  ... batteries are very long lasting the price ...           Bylinda

# %%
from wordcloud import WordCloud

# %%
rt = senti['reviews_title']
wordcloud = WordCloud(background_color='white',width=1000, height=400
                        ).generate(" ".join(rt))
plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.title('All Words in the Reviews\n',size=20)
plt.axis('off')
plt.show()
